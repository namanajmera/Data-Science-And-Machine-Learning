# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("china_gdp 1.csv")
df.head()
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10

# %%
plt.scatter(df["Year"], df["Value"], c = "red")

# %%
import seaborn as sns

# %%
sns.set(style = "whitegrid")

# %%
sns.regplot(df["Year"], df["Value"], marker = "*", color = 'red')
